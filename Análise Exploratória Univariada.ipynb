# %% [markdown]
# # Importando

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

# %%
df = pd.read_csv('table_ABSENTEEISM.csv', sep=';', encoding='UTF-8')
df.head()
# Out:
#    ID  Reason_for_absence  Month_of_absence  Day_of_the_week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation_expense  Distance_from_Residence_to_Work  Service_time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#   Work_load_Average_day  ...  Disciplinary_failure  Education  Son  \
# 0               239,554  ...                     0          1    2
# 1               239,554  ...                     1          1    1
# 2               239,554  ...                     0          1    0
# 3               239,554  ...                     0          1    2
# 4               239,554  ...                     0          1    2
#
#    Social_drinker  Social_smoker  Pet  Weight  Height  Body_mass_index  \
# 0               1              0    1      90     172               30
# 1               1              0    0      98     178               31
# 2               1              0    0      89     170               31
# 3               1              1    0      68     168               24
# 4               1              0    1      90     172               30
#
#    Absenteeism_time_in_hours
# 0                          4
# 1                          0
# 2                          2
# 3                          4
# 4                          2
#
# [5 rows x 21 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason_for_absence               740 non-null    int64
#  2   Month_of_absence                 740 non-null    int64
#  3   Day_of_the_week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation_expense           740 non-null    int64
#  6   Distance_from_Residence_to_Work  740 non-null    int64
#  7   Service_time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work_load_Average_day            740 non-null    object
#  10  Hit_target                       740 non-null    int64
#  11  Disciplinary_failure             740 non-null    int64
#  12  Education                        740 non-null    int64
#  13  Son                              740 non-null    int64
#  14  Social_drinker                   740 non-null    int64
#  15  Social_smoker                    740 non-null    int64
#  16  Pet                              740 non-null    int64
#  17  Weight                           740 non-null    int64
#  18  Height                           740 non-null    int64
#  19  Body_mass_index                  740 non-null    int64
#  20  Absenteeism_time_in_hours        740 non-null    int64
# dtypes: int64(20), object(1)
# memory usage: 121.5+ KB
#                ID  Reason_for_absence  Month_of_absence  Day_of_the_week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation_expense  Distance_from_Residence_to_Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# min      1.000000              118.000000                         5.000000
# 25%      2.000000              179.000000                        16.000000
# 50%      3.000000              225.000000                        26.000000
# 75%      4.000000              260.000000                        50.000000
# max      4.000000              388.000000                        52.000000
#
#        Service_time         Age  Hit_target  Disciplinary_failure   Education  \
# count    740.000000  740.000000  740.000000            740.000000  740.000000
# mean      12.554054   36.450000   94.587838              0.054054    1.291892
# std        4.384873    6.478772    3.779313              0.226277    0.673238
# min        1.000000   27.000000   81.000000              0.000000    1.000000
# 25%        9.000000   31.000000   93.000000              0.000000    1.000000
# 50%       13.000000   37.000000   95.000000              0.000000    1.000000
# 75%       16.000000   40.000000   97.000000              0.000000    1.000000
# max       29.000000   58.000000  100.000000              1.000000    4.000000
#
#               Son  Social_drinker  Social_smoker         Pet      Weight  \
# count  740.000000      740.000000     740.000000  740.000000  740.000000
# mean     1.018919        0.567568       0.072973    0.745946   79.035135
# std      1.098489        0.495749       0.260268    1.318258   12.883211
# min      0.000000        0.000000       0.000000    0.000000   56.000000
# 25%      0.000000        0.000000       0.000000    0.000000   69.000000
# 50%      1.000000        1.000000       0.000000    0.000000   83.000000
# 75%      2.000000        1.000000       0.000000    1.000000   89.000000
# max      4.000000        1.000000       1.000000    8.000000  108.000000
#
#            Height  Body_mass_index  Absenteeism_time_in_hours
# count  740.000000       740.000000                 740.000000
# mean   172.114865        26.677027                   6.924324
# std      6.034995         4.285452                  13.330998
# min    163.000000        19.000000                   0.000000
# 25%    169.000000        24.000000                   2.000000
# 50%    170.000000        25.000000                   3.000000
# 75%    172.000000        31.000000                   8.000000
# max    196.000000        38.000000                 120.000000

# %% [markdown]
# # Tratamento

# %%
# Adicionando a coluna estação do ano

def mes_para_periodo(mes):
    if mes in [12, 1, 2]:
        return 'Verão'
    elif mes in [3, 4, 5]:
        return 'Outono'
    elif mes in [6, 7, 8]:
        return 'Inverno'
    else:
        return 'Primavera'

df['Season_from_month'] = df['Month_of_absence'].apply(mes_para_periodo)

# %% [markdown]
# # Análises de distribuição

# %%
# Box plot abstenteismo em horas

fig, ax = plt.subplots(figsize = (9,7))

ax.set_title("Boxplot Abstenteísmo em horas", fontsize = 16)

ax.boxplot(df['Absenteeism_time_in_hours'])

plt.show()

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.set_title("Histograma Absenteismo em horas")

ax.hist(df['Absenteeism_time_in_hours'])

plt.show()

# %%
# Histrograma principal

data = df['Absenteeism_time_in_hours']

bins = np.linspace(0, data.max(), 30)

fig, ax = plt.subplots(figsize = (9,5))

# Histograma em frequência
counts, bins, _ = ax.hist(data, bins=bins, color='lightblue', edgecolor='black')

# KDE escalada para frequência
kde = sns.kdeplot(data, color='blue', linewidth=2, clip=(0, None))

# Ajustar escala da KDE
line = kde.get_lines()[0]
line.set_ydata(line.get_ydata() * len(data) * (bins[1] - bins[0]))

plt.xlim(left=0)

ax.set_title('Distribuição do Tempo de Ausência', fontsize = 16)
ax.set_xlabel('Tempo de Ausência (horas)')
ax.set_ylabel('Frequência')

# salvar imagem
fig.savefig('figures/histograma_absenteismo.png', 
            dpi=300, 
            bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Box plots seaborn

# %%
sns.boxplot(x=df['Absenteeism_time_in_hours'])

plt.title('Boxplot - Absenteeism Time in Hours')
plt.show()

# %% [markdown]
# ## Para várias variáveis de uma vez

# %%
cols = [
    'Absenteeism_time_in_hours',
    'Age',
    'Transportation_expense',
    'Distance_from_Residence_to_Work'
]

df[cols].plot(kind='box', subplots=True, layout=(2,2), figsize=(10,8))
plt.show()

# %% [markdown]
# ## Boxplot por categoria

# %%
sns.boxplot(
    x='Reason_for_absence',
    y='Absenteeism_time_in_hours',
    data=df
)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Gráfico de barras para Reason_for_absence

# %%
# Dicionário de tradução
motivos = {
    1: 'Doenças infecciosas',
    2: 'Neoplasias',
    3: 'Doenças do sangue',
    4: 'Doenças endócrinas',
    5: 'Transtornos mentais',
    6: 'Sistema nervoso',
    7: 'Olhos',
    8: 'Ouvido',
    9: 'Sistema circulatório',
    10: 'Sistema respiratório',
    11: 'Sistema digestivo',
    12: 'Pele',
    13: 'Musculoesquelético',
    14: 'Geniturinário',
    15: 'Gravidez/parto',
    16: 'Perinatais',
    17: 'Malformações',
    18: 'Sintomas não classificados',
    19: 'Lesões',
    20: 'Causas externas',
    21: 'Fatores de saúde',
    22: 'Acompanhamento',
    23: 'Consulta médica',
    24: 'Doação de sangue',
    25: 'Exame laboratorial',
    26: 'Injustificada',
    27: 'Fisioterapia',
    28: 'Consulta odontológica'
}

# %%
# garantir que o código é numérico (evita "13" como string)
df['Reason_for_absence'] = pd.to_numeric(df['Reason_for_absence'], errors='coerce').astype('Int64')

# frequência REAL (base inteira), garantindo todos os códigos 1..28
freq = (
    df['Reason_for_absence']
    .value_counts()
    .reindex(motivos.keys(), fill_value=0)  # inclui os 28 mesmo que algum tenha 0
    .sort_values(ascending=False)           # maior -> menor
)

# %%
# plot: eixo X só com códigos
fig, ax = plt.subplots(figsize=(15, 6))
ax.bar(freq.index.astype(str), freq.values, color='lightblue', edgecolor='black')

ax.set_title('Frequência real dos motivos de ausência (toda a base)', fontsize = 16)
ax.set_xlabel('Código do motivo')
ax.set_ylabel('Quantidade de registros')
ax.tick_params(axis='x', rotation=0, labelsize=9)  # códigos “retinhos”

# ---- legenda à ESQUERDA (códigos -> descrições) ----
legenda = "\n".join([f"{k:>2}: {v}" for k, v in motivos.items()])

# abre espaço à esquerda para caber a legenda
fig.subplots_adjust(left=0.35, right=0.98, bottom=0.15)

# coloca o texto da legenda no lado esquerdo
fig.text(
    0.02, 0.5, legenda,
    fontsize=12, va='center', ha='left',
    family='monospace'
)

# salvar
plt.savefig('figures/frequencia_motivos_real.png', 
            dpi=300, 
            bbox_inches='tight'
            )

plt.show()

# %% [markdown]
# # Identificar outliers com IQR

# %%
Q1 = df['Absenteeism_time_in_hours'].quantile(0.25)
Q3 = df['Absenteeism_time_in_hours'].quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers = df[
    (df['Absenteeism_time_in_hours'] < limite_inferior) |
    (df['Absenteeism_time_in_hours'] > limite_superior)
]

print(outliers)
# Out:
#      ID  Reason_for_absence  Month_of_absence  Day_of_the_week  Seasons  \
# 8    14                  19                 7                2        1
# 22   10                  13                 8                2        1
# 49   15                  14                 9                2        4
# 85   14                  10                11                2        4
# 87   15                  14                11                2        4
# 96   11                   7                11                4        4
# 99   34                  19                12                3        4
# 104  34                  19                12                3        4
# 163  20                  13                 3                6        2
# 164  17                  11                 3                2        2
# 173   3                  13                 3                3        2
# 187  24                  13                 4                4        3
# 191   3                  13                 4                4        3
# 197  20                  19                 4                6        3
# 199  14                  12                 4                4        3
# 212  11                  13                 5                4        3
# 218  36                  13                 5                4        3
# 222  24                  10                 6                3        3
# 231  36                  13                 6                4        3
# 249  11                  19                 7                2        1
# 272  11                  19                 9                4        1
# 279  24                   9                 9                4        1
# 287  15                   7                 9                2        4
# 299  22                   1                10                4        4
# 323  14                  11                11                2        4
# 359  34                  19                 1                2        2
# 387  24                  10                 2                6        2
# 420  36                  13                 4                4        3
# 447  15                  13                 6                2        3
# 448   3                  28                 6                2        3
# 471  28                   9                 7                3        1
# 534  18                   2                11                4        4
# 555   3                  13                12                3        4
# 569  14                  18                12                3        2
# 570  22                  12                 1                2        2
# 622   9                  12                 3                3        2
# 648  14                  13                 3                4        3
# 652  11                  19                 3                2        3
# 660  13                   7                 4                2        3
# 682  26                  19                 5                6        3
# 692  14                  10                 5                2        3
# 711  36                  19                 6                5        3
# 729   9                   6                 7                3        1
# 734  13                  13                 7                2        1
#
#      Transportation_expense  Distance_from_Residence_to_Work  Service_time  \
# 8                       155                               12            14
# 22                      361                               52             3
# 49                      291                               31            12
# 85                      155                               12            14
# 87                      291                               31            12
# 96                      289                               36            13
# 99                      118                               10            10
# 104                     118                               10            10
# 163                     260                               50            11
# 164                     179                               22            17
# 173                     179                               51            18
# 187                     246                               25            16
# 191                     179                               51            18
# 197                     260                               50            11
# 199                     155                               12            14
# 212                     289                               36            13
# 218                     118                               13            18
# 222                     246                               25            16
# 231                     118                               13            18
# 249                     289                               36            13
# 272                     289                               36            13
# 279                     246                               25            16
# 287                     291                               31            12
# 299                     179                               26             9
# 323                     155                               12            14
# 359                     118                               10            10
# 387                     246                               25            16
# 420                     118                               13            18
# 447                     291                               31            12
# 448                     179                               51            18
# 471                     225                               26             9
# 534                     330                               16             4
# 555                     179                               51            18
# 569                     155                               12            14
# 570                     179                               26             9
# 622                     228                               14            16
# 648                     155                               12            14
# 652                     289                               36            13
# 660                     369                               17            12
# 682                     300                               26            13
# 692                     155                               12            14
# 711                     118                               13            18
# 729                     228                               14            16
# 734                     369                               17            12
#
#      Age Work_load_Average_day  ...  Education  Son  Social_drinker  \
# 8     34               239,554  ...          1    2               1
# 22    28               205,917  ...          1    1               1
# 49    40               241,476  ...          1    1               1
# 85    34               306,345  ...          1    2               1
# 87    40               306,345  ...          1    1               1
# 96    33               306,345  ...          1    2               1
# 99    37               261,306  ...          1    0               0
# 104   37               261,306  ...          1    0               0
# 163   36               343,253  ...          1    4               1
# 164   40               343,253  ...          2    2               0
# 173   38               343,253  ...          1    0               1
# 187   41               326,452  ...          1    0               1
# 191   38               326,452  ...          1    0               1
# 197   36               326,452  ...          1    4               1
# 199   34               326,452  ...          1    2               1
# 212   33               378,884  ...          1    2               1
# 218   50               378,884  ...          1    1               1
# 222   41               377,550  ...          1    0               1
# 231   50               377,550  ...          1    1               1
# 249   33               275,312  ...          1    2               1
# 272   33               294,217  ...          1    2               1
# 279   41               294,217  ...          1    0               1
# 287   40               294,217  ...          1    1               1
# 299   30               265,017  ...          3    0               0
# 323   34               284,031  ...          1    2               1
# 359   37               330,061  ...          1    0               0
# 387   41               251,818  ...          1    0               1
# 420   50               239,409  ...          1    1               1
# 447   40               253,957  ...          1    1               1
# 448   38               253,957  ...          1    0               1
# 471   28               230,290  ...          1    1               0
# 534   28               268,519  ...          2    0               0
# 555   38               280,549  ...          1    0               1
# 569   34               280,549  ...          1    2               1
# 570   30               313,532  ...          3    0               0
# 622   58               222,196  ...          1    2               0
# 648   34               222,196  ...          1    2               1
# 652   33               222,196  ...          1    2               1
# 660   31               246,288  ...          1    3               1
# 682   43               237,656  ...          1    2               1
# 692   34               237,656  ...          1    2               1
# 711   50               275,089  ...          1    1               1
# 729   58               264,604  ...          1    2               0
# 734   31               264,604  ...          1    3               1
#
#      Social_smoker  Pet  Weight  Height  Body_mass_index  \
# 8                0    0      95     196               25
# 22               0    4      80     172               27
# 49               0    1      73     171               25
# 85               0    0      95     196               25
# 87               0    1      73     171               25
# 96               0    1      90     172               30
# 99               0    0      83     172               28
# 104              0    0      83     172               28
# 163              0    0      65     168               23
# 164              1    0      63     170               22
# 173              0    0      89     170               31
# 187              0    0      67     170               23
# 191              0    0      89     170               31
# 197              0    0      65     168               23
# 199              0    0      95     196               25
# 212              0    1      90     172               30
# 218              0    0      98     178               31
# 222              0    0      67     170               23
# 231              0    0      98     178               31
# 249              0    1      90     172               30
# 272              0    1      90     172               30
# 279              0    0      67     170               23
# 287              0    1      73     171               25
# 299              0    0      56     171               19
# 323              0    0      95     196               25
# 359              0    0      83     172               28
# 387              0    0      67     170               23
# 420              0    0      98     178               31
# 447              0    1      73     171               25
# 448              0    0      89     170               31
# 471              0    2      69     169               24
# 534              0    0      84     182               25
# 555              0    0      89     170               31
# 569              0    0      95     196               25
# 570              0    0      56     171               19
# 622              0    1      65     172               22
# 648              0    0      95     196               25
# 652              0    1      90     172               30
# 660              0    0      70     169               25
# 682              1    1      77     175               25
# 692              0    0      95     196               25
# 711              0    0      98     178               31
# 729              0    1      65     172               22
# 734              0    0      70     169               25
#
#      Absenteeism_time_in_hours  Season_from_month
# 8                           40            Inverno
# 22                          40            Inverno
# 49                          32          Primavera
# 85                          32          Primavera
# 87                          40          Primavera
# 96                          24          Primavera
# 99                          64              Verão
# 104                         56              Verão
# 163                         40             Outono
# 164                         40             Outono
# 173                         24             Outono
# 187                         24             Outono
# 191                         24             Outono
# 197                         56             Outono
# 199                         24             Outono
# 212                         24             Outono
# 218                         24             Outono
# 222                         24            Inverno
# 231                         80            Inverno
# 249                         32            Inverno
# 272                         24          Primavera
# 279                         32          Primavera
# 287                         40          Primavera
# 299                         64          Primavera
# 323                        120          Primavera
# 359                         32              Verão
# 387                         24              Verão
# 420                        120             Outono
# 447                         40            Inverno
# 448                         24            Inverno
# 471                        112            Inverno
# 534                         24          Primavera
# 555                         32              Verão
# 569                         80              Verão
# 570                         24              Verão
# 622                        112             Outono
# 648                         24             Outono
# 652                        104             Outono
# 660                         24             Outono
# 682                         64             Outono
# 692                         48             Outono
# 711                         24            Inverno
# 729                        120            Inverno
# 734                         80            Inverno
#
# [44 rows x 22 columns]

# %%
q3 = df['Absenteeism_time_in_hours'].quantile(0.75)

top = df[df['Absenteeism_time_in_hours'] > q3]
freq = top['Reason_for_absence'].value_counts()

import seaborn as sns

plt.figure(figsize=(10,5))

sns.countplot(
    x='Reason_for_absence',
    data=top,
    order=top['Reason_for_absence'].value_counts().index,
    color='lightblue'
)

plt.title('Motivos mais frequentes nas maiores ausências')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# # Winsorização

# %%
horas_absenteismo_winsorizado = df['Absenteeism_time_in_hours'].clip(
    lower=limite_inferior,
    upper=limite_superior
)

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.set_title("Boxplot ausência em horas após winsorização", fontsize = 16)

ax.boxplot(horas_absenteismo_winsorizado)

fig.savefig('figures/Boxplot_Absenteismo_após_winsorização.png', 
            dpi=300,
            bbox_inches = 'tight')

plt.show()

# %%
fig, ax = plt.subplots(figsize = (15,5),nrows=1, ncols=2)

ax[1].set_title("Boxplot ausência em horas após winsorização", fontsize = 16)

ax[1].boxplot(horas_absenteismo_winsorizado)

ax[0].set_title("Boxplot ausência em horas sem winsorização", fontsize = 16)

ax[0].boxplot(df['Absenteeism_time_in_hours'])

fig.tight_layout()

fig.savefig('figures/Comparação_Boxplots_winsorização.png', 
            dpi=300,
            bbox_inches = 'tight')

plt.show()

# %% [markdown]
# # Gráficos de dispersão

# %%
df_numerico = df[['Transportation_expense','Distance_from_Residence_to_Work','Service_time','Age','Hit_target','Education','Son','Social_drinker','Social_smoker','Pet','Weight','Height','Body_mass_index','Absenteeism_time_in_hours']].copy()

matriz = df_numerico.corr(method='pearson')
print(matriz)
# Out:
#                                  Transportation_expense  \
# Transportation_expense                         1.000000
# Distance_from_Residence_to_Work                0.262183
# Service_time                                  -0.349887
# Age                                           -0.227542
# Hit_target                                    -0.080193
# Education                                     -0.055065
# Son                                            0.383001
# Social_drinker                                 0.145117
# Social_smoker                                  0.044356
# Pet                                            0.400080
# Weight                                        -0.207435
# Height                                        -0.194496
# Body_mass_index                               -0.136517
# Absenteeism_time_in_hours                      0.027585
#
#                                  Distance_from_Residence_to_Work  \
# Transportation_expense                                  0.262183
# Distance_from_Residence_to_Work                         1.000000
# Service_time                                            0.131730
# Age                                                    -0.145886
# Hit_target                                             -0.013865
# Education                                              -0.259605
# Son                                                     0.054230
# Social_drinker                                          0.452196
# Social_smoker                                          -0.075369
# Pet                                                     0.205941
# Weight                                                 -0.047859
# Height                                                 -0.353372
# Body_mass_index                                         0.113772
# Absenteeism_time_in_hours                              -0.088363
#
#                                  Service_time       Age  Hit_target  \
# Transportation_expense              -0.349887 -0.227542   -0.080193
# Distance_from_Residence_to_Work      0.131730 -0.145886   -0.013865
# Service_time                         1.000000  0.670979   -0.007840
# Age                                  0.670979  1.000000   -0.039224
# Hit_target                          -0.007840 -0.039224    1.000000
# Education                           -0.213000 -0.221882    0.101062
# Son                                 -0.047128  0.056984   -0.014091
# Social_drinker                       0.353141  0.213183   -0.102480
# Social_smoker                        0.072424  0.121738    0.051254
# Pet                                 -0.440301 -0.231226    0.007201
# Weight                               0.455975  0.418730   -0.044947
# Height                              -0.053135 -0.062997    0.093267
# Body_mass_index                      0.499718  0.470688   -0.088939
# Absenteeism_time_in_hours            0.019029  0.065760    0.026695
#
#                                  Education       Son  Social_drinker  \
# Transportation_expense           -0.055065  0.383001        0.145117
# Distance_from_Residence_to_Work  -0.259605  0.054230        0.452196
# Service_time                     -0.213000 -0.047128        0.353141
# Age                              -0.221882  0.056984        0.213183
# Hit_target                        0.101062 -0.014091       -0.102480
# Education                         1.000000 -0.188622       -0.420013
# Son                              -0.188622  1.000000        0.206376
# Social_drinker                   -0.420013  0.206376        1.000000
# Social_smoker                     0.032727  0.156088       -0.111678
# Pet                              -0.053554  0.108917       -0.122780
# Weight                           -0.300574 -0.139552        0.378664
# Height                            0.100977 -0.014208        0.169951
# Body_mass_index                  -0.366884 -0.144150        0.323978
# Absenteeism_time_in_hours        -0.046235  0.113756        0.065067
#
#                                  Social_smoker       Pet    Weight    Height  \
# Transportation_expense                0.044356  0.400080 -0.207435 -0.194496
# Distance_from_Residence_to_Work      -0.075369  0.205941 -0.047859 -0.353372
# Service_time                          0.072424 -0.440301  0.455975 -0.053135
# Age                                   0.121738 -0.231226  0.418730 -0.062997
# Hit_target                            0.051254  0.007201 -0.044947  0.093267
# Education                             0.032727 -0.053554 -0.300574  0.100977
# Son                                   0.156088  0.108917 -0.139552 -0.014208
# Social_drinker                       -0.111678 -0.122780  0.378664  0.169951
# Social_smoker                         1.000000  0.105379 -0.198511  0.003271
# Pet                                   0.105379  1.000000 -0.103770 -0.103143
# Weight                               -0.198511 -0.103770  1.000000  0.306802
# Height                                0.003271 -0.103143  0.306802  1.000000
# Body_mass_index                      -0.196006 -0.076103  0.904117 -0.121049
# Absenteeism_time_in_hours            -0.008936 -0.028277  0.015789  0.144420
#
#                                  Body_mass_index  Absenteeism_time_in_hours
# Transportation_expense                 -0.136517                   0.027585
# Distance_from_Residence_to_Work         0.113772                  -0.088363
# Service_time                            0.499718                   0.019029
# Age                                     0.470688                   0.065760
# Hit_target                             -0.088939                   0.026695
# Education                              -0.366884                  -0.046235
# Son                                    -0.144150                   0.113756
# Social_drinker                          0.323978                   0.065067
# Social_smoker                          -0.196006                  -0.008936
# Pet                                    -0.076103                  -0.028277
# Weight                                  0.904117                   0.015789
# Height                                 -0.121049                   0.144420
# Body_mass_index                         1.000000                  -0.049719
# Absenteeism_time_in_hours              -0.049719                   1.000000

# %%
corr_linha = df_numerico.corr(method='pearson')['Absenteeism_time_in_hours']

# %%
corr_linha = corr_linha.to_frame().T

# %%
plt.figure(figsize=(12,10))
sns.heatmap(matriz, 
            cmap='coolwarm',
            annot=True,
            )

plt.savefig('figures/Heatmap.png', 
            dpi=300,
            bbox_inches = 'tight')

plt.xticks(rotation=45, ha='right') 

plt.show()
